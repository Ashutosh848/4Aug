# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users//delli//Downloads//h1b_kaggle.csv//h1b_kaggle.csv")

# %%
df
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# ...             ...                  ...
# 3002453     3002454                  NaN
# 3002454     3002455                  NaN
# 3002455     3002456                  NaN
# 3002456     3002457                  NaN
# 3002457     3002458                  NaN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002453                  NaN
# 3002454                  NaN
# 3002455                  NaN
# 3002456                  NaN
# 3002457                  NaN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002453                                                NaN
# 3002454                                                NaN
# 3002455                                                NaN
# ...

# %%
df.shape
# Out:
# (3002458, 10)

# %%
df.dropna(inplace=True)

# %%
df.head(5)
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# ...

# %%
df.shape
# Out:
# (2877765, 10)

# %%
df['EMPLOYER_NAME'].value_counts().head(15)
# Out:
# EMPLOYER_NAME
# INFOSYS LIMITED                                    130257
# TATA CONSULTANCY SERVICES LIMITED                   64273
# WIPRO LIMITED                                       45673
# DELOITTE CONSULTING LLP                             35999
# IBM INDIA PRIVATE LIMITED                           33585
# ACCENTURE LLP                                       33226
# MICROSOFT CORPORATION                               25551
# HCL AMERICA, INC.                                   22488
# ERNST & YOUNG U.S. LLP                              18094
# COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION     17322
# CAPGEMINI AMERICA INC                               16628
# GOOGLE INC.                                         16425
# LARSEN & TOUBRO INFOTECH LIMITED                    14318
# IGATE TECHNOLOGIES INC.                             12327
# IBM CORPORATION                                     11976
# Name: count, dtype: int64

# %%
colors = ['red', 'blue', 'green', 'orange', 'purple']
df['EMPLOYER_NAME'].value_counts().head(15).plot(kind = 'bar',title = "Top 15 Companies",legend = False,color = colors,figsize = (4,4))
# Out:
# <Axes: title={'center': 'Top 15 Companies'}, xlabel='EMPLOYER_NAME'>

# %%
df['PREVAILING_WAGE'].value_counts().head(15)
# Out:
# PREVAILING_WAGE
# 60000.0    10185
# 55245.0     6745
# 62566.0     6480
# 58053.0     5683
# 52499.0     5492
# 51730.0     5407
# 63877.0     5377
# 65042.0     5276
# 55370.0     4961
# 67808.0     4646
# 67621.0     4603
# 60133.0     4505
# 63086.0     4414
# 73923.0     4401
# 66602.0     4105
# Name: count, dtype: int64

# %%
df['PREVAILING_WAGE'].mean()
# Out:
# 145166.64888401062

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %%
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# ...

# %%
df['WORKSITE'].value_counts().head(5).plot(kind = 'bar',color = colors,legend = False,figsize=(4,4),title="Top 5 worksite Companies")
# Out:
# <Axes: title={'center': 'Top 5 worksite Companies'}, xlabel='WORKSITE'>

# %%
df['WORKSITE'].head()
# Out:
# 0        ANN ARBOR, MICHIGAN
# 1               PLANO, TEXAS
# 2    JERSEY CITY, NEW JERSEY
# 3           DENVER, COLORADO
# 4        ST. LOUIS, MISSOURI
# Name: WORKSITE, dtype: object

# %%
df['WORKSITE'].apply(lambda x:x.split(',')[1].strip())
# Out:
# 0               MICHIGAN
# 1                  TEXAS
# 2             NEW JERSEY
# 3               COLORADO
# 4               MISSOURI
#                ...
# 3002440       CALIFORNIA
# 3002441             UTAH
# 3002442             OHIO
# 3002443    MASSACHUSETTS
# 3002444    MASSACHUSETTS
# Name: WORKSITE, Length: 2877765, dtype: object

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002440            WITHDRAWN
# 3002441            WITHDRAWN
# 3002442            WITHDRAWN
# 3002443            WITHDRAWN
# 3002444            WITHDRAWN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002440                               ORACLE AMERICA, INC.
# 3002441                                 B & D DENTAL CORP.
# 3002442                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %%
df.fillna('MARIANA ISLANDS',inplace = True)

# %%
df['WORKSITE'].unique()
# Out:
# array(['ANN ARBOR, MICHIGAN', 'PLANO, TEXAS', 'JERSEY CITY, NEW JERSEY',
#        ..., 'NEW  YORK, NEW YORK', 'FAIRLESS HLS, PENNSYLVANIA',
#        'MILIPITAS, CALIFORNIA'], dtype=object)

# %%
df.rename(columns = {'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'},inplace = True)

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'YEAR', 'STATE', 'LON', 'LAT'],
#       dtype='object')

# %%
df.head()
# Out:
#            CASE_STATUS                                           EMPLOYER  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE FULL_T  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW      N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER      Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER      Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS      Y
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA      Y
#
#    PREV_WAGE    YEAR                    STATE         LON        LAT
# ...

# %%
df.astype({'LON':float,'LAT':float,'YEAR':str,'PREV_WAGE':int})
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002440            WITHDRAWN
# 3002441            WITHDRAWN
# 3002442            WITHDRAWN
# 3002443            WITHDRAWN
# 3002444            WITHDRAWN
#
#                                                   EMPLOYER  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002440                               ORACLE AMERICA, INC.
# 3002441                                 B & D DENTAL CORP.
# 3002442                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002440            WITHDRAWN
# 3002441            WITHDRAWN
# 3002442            WITHDRAWN
# 3002443            WITHDRAWN
# 3002444            WITHDRAWN
#
#                                                   EMPLOYER  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002440                               ORACLE AMERICA, INC.
# 3002441                                 B & D DENTAL CORP.
# 3002442                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %%
df['LAT']=df['LAT'].round(2)

# %%
df['LON']=df['LON'].round(2)

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002440            WITHDRAWN
# 3002441            WITHDRAWN
# 3002442            WITHDRAWN
# 3002443            WITHDRAWN
# 3002444            WITHDRAWN
#
#                                                   EMPLOYER  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002440                               ORACLE AMERICA, INC.
# 3002441                                 B & D DENTAL CORP.
# 3002442                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %%
df['CASE_STATUS'].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %%
df['CASE_STATUS'].value_counts()
# Out:
# CASE_STATUS
# CERTIFIED                                             2512114
# CERTIFIED-WITHDRAWN                                    195721
# DENIED                                                  85161
# WITHDRAWN                                               84752
# PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED         15
# REJECTED                                                    1
# INVALIDATED                                                 1
# Name: count, dtype: int64
