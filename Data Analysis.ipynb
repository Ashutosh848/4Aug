# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users//delli//Downloads//h1b_kaggle.csv//h1b_kaggle.csv")

# %%
df
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# ...             ...                  ...
# 3002453     3002454                  NaN
# 3002454     3002455                  NaN
# 3002455     3002456                  NaN
# 3002456     3002457                  NaN
# 3002457     3002458                  NaN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace = True)

# %%
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 3002453                  NaN
# 3002454                  NaN
# 3002455                  NaN
# 3002456                  NaN
# 3002457                  NaN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 3002453                                                NaN
# 3002454                                                NaN
# 3002455                                                NaN
# ...

# %%
df.dropna(inplace = True)

# %%
df.head(4)
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# 0                  N          36067.0  2016.0      ANN ARBOR, MICHIGAN
# 1                  Y         242674.0  2016.0             PLANO, TEXAS
# ...

# %%
df.shape[0]
# Out:
# 2877765

# %%
df['EMPLOYER_NAME'].value_counts().head(15)
# Out:
# EMPLOYER_NAME
# INFOSYS LIMITED                                    130257
# TATA CONSULTANCY SERVICES LIMITED                   64273
# WIPRO LIMITED                                       45673
# DELOITTE CONSULTING LLP                             35999
# IBM INDIA PRIVATE LIMITED                           33585
# ACCENTURE LLP                                       33226
# MICROSOFT CORPORATION                               25551
# HCL AMERICA, INC.                                   22488
# ERNST & YOUNG U.S. LLP                              18094
# COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION     17322
# CAPGEMINI AMERICA INC                               16628
# GOOGLE INC.                                         16425
# LARSEN & TOUBRO INFOTECH LIMITED                    14318
# IGATE TECHNOLOGIES INC.                             12327
# IBM CORPORATION                                     11976
# Name: count, dtype: int64

# %%
colors = ['red', 'blue', 'green', 'orange', 'purple']
df['EMPLOYER_NAME'].value_counts().head(15).plot(kind = 'bar',color = colors,legend = False,figsize = (3,3))
# Out:
# <Axes: xlabel='EMPLOYER_NAME'>

# %%
df['PREVAILING_WAGE'].value_counts().head(5)
# Out:
# PREVAILING_WAGE
# 60000.0    10185
# 55245.0     6745
# 62566.0     6480
# 58053.0     5683
# 52499.0     5492
# Name: count, dtype: int64

# %%
df['PREVAILING_WAGE'].mean().round(3)
# Out:
# 145166.649

# %%
df['WORKSITE'].value_counts().head(5).plot(kind = 'bar',color = colors,figsize = (3,3),legend = False)
# Out:
# <Axes: xlabel='WORKSITE'>

# %%
df['WORKSITE'].apply(lambda x:x.split(',')[1].strip())
# Out:
# 0               MICHIGAN
# 1                  TEXAS
# 2             NEW JERSEY
# 3               COLORADO
# 4               MISSOURI
#                ...
# 3002440       CALIFORNIA
# 3002441             UTAH
# 3002442             OHIO
# 3002443    MASSACHUSETTS
# 3002444    MASSACHUSETTS
# Name: WORKSITE, Length: 2877765, dtype: object

# %%
df['WORKSITE'].fillna("MARIANA ISLANDS",inplace = True)

# %%
df.head(5)
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# ...

# %%
df['WORKSITE'].unique()
# Out:
# array(['ANN ARBOR, MICHIGAN', 'PLANO, TEXAS', 'JERSEY CITY, NEW JERSEY',
#        ..., 'NEW  YORK, NEW YORK', 'FAIRLESS HLS, PENNSYLVANIA',
#        'MILIPITAS, CALIFORNIA'], dtype=object)

# %%
df.rename(columns={'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'},inplace = True)

# %%
df['LAT']=df['LAT'].round(2)
df['LON']=df['LON'].round(2)

# %%
df.head(4)
# Out:
#            CASE_STATUS                                           EMPLOYER  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
#
#                         SOC_NAME                     JOB_TITLE FULL_T  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW      N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER      Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER      Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS      Y
#
#    PREV_WAGE    YEAR                    STATE     LON    LAT
# 0    36067.0  2016.0      ANN ARBOR, MICHIGAN  -83.74  42.28
# 1   242674.0  2016.0             PLANO, TEXAS  -96.70  33.02
# ...

# %%
df.astype({'YEAR':str,'PREV_WAGE':int}).head(4)
# Out:
#            CASE_STATUS                                           EMPLOYER  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
#
#                         SOC_NAME                     JOB_TITLE FULL_T  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW      N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER      Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER      Y
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS      Y
#
#    PREV_WAGE    YEAR                    STATE     LON    LAT
# 0      36067  2016.0      ANN ARBOR, MICHIGAN  -83.74  42.28
# 1     242674  2016.0             PLANO, TEXAS  -96.70  33.02
# ...

# %%
df_pie=df['CASE_STATUS'].value_counts()
df_pie
# Out:
# CASE_STATUS
# CERTIFIED                                             2512114
# CERTIFIED-WITHDRAWN                                    195721
# DENIED                                                  85161
# WITHDRAWN                                               84752
# PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED         15
# REJECTED                                                    1
# INVALIDATED                                                 1
# Name: count, dtype: int64

# %%
plt.figure(figsize = (4,3))
plt.pie(df_pie,startangle =140)
plt.axis('equal')
plt.title('Case_status')
plt.show()

# %%
df_hist=df['YEAR'].value_counts().array

# %%
plt.figure(figsize = (6,6))
plt.hist(df_hist)
plt.show()

# %%
df['JOB_TITLE'].head(12).plot(kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 df['JOB_TITLE'].head(12).plot(kind = 'hist')
#
# File D:\Anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File D:\Anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File D:\Anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:451, in MPLPlot.generate(self)
#     449 def generate(self) -> None:
# ...
